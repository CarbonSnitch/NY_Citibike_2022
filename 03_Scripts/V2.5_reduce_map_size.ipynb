# %% [markdown]
# # Making a Kepler map = python 3.11, numpy version 1.23.5

# %%
import pandas as pd
import os
from keplergl import KeplerGl
from pyproj import CRS
import numpy as np
from matplotlib import pyplot as plt
import importlib.resources
from IPython.display import HTML, display
   
def _get_asset_str(filepath: str) -> bytes:
    pkg, sub = 'keplergl.keplergl', filepath
    return importlib.resources.read_binary(pkg, sub)

# %%
path = r"C:\Users\ryani\Desktop\JupyterLab\NY_Citibike_2022"

# %%
df = pd.read_csv(os.path.join(path, '02_Prepared_Data', 'reduced_df.csv'), index_col=0, low_memory=False,
dtype={
        "start_station_name": "string",
        "end_station_name": "string"})

df
# Out:
#                    ride_id  rideable_type               started_at  \
# 23031359  51561596962D6D34   classic_bike  2022-10-19 19:05:17.329
# 4214833   8EC10B67BE1C76F4   classic_bike  2022-04-13 14:57:39.816
# 27380825  D8E629127787A5D5   classic_bike  2022-11-12 16:07:20.481
# 26400613  4FF2A3FCAC3D21C6  electric_bike  2022-11-09 07:24:23.803
# 28333068  0FCCB939FC94D28C  electric_bike  2022-12-29 14:49:21.643
# ...                    ...            ...                      ...
# 17567286  8686ABE8ACE7AA7A   classic_bike  2022-08-01 15:48:27.651
# 15851894  BB5E7E58723263A5   classic_bike  2022-07-29 14:52:06.128
# 13043140  67583EEF35D34EF0   classic_bike  2022-07-26 12:21:12.289
# 12892275  BEF5594676FB8722   classic_bike  2022-07-24 13:07:01.807
# 24144820  80633A94BB5EA1DF   classic_bike  2022-10-11 08:26:44.238
#
#                          ended_at           start_station_name  \
# 23031359  2022-10-19 19:10:58.132           Broadway & E 21 St
# 4214833   2022-04-13 15:43:47.279              W 22 St & 8 Ave
# 27380825  2022-11-12 16:18:02.598        Little West St & 1 Pl
# 26400613  2022-11-09 07:32:16.316          Morton St & West St
# 28333068  2022-12-29 14:54:01.034     Wadsworth Ave & W 179 St
# ...                           ...                          ...
# 17567286  2022-08-01 15:55:53.935  Central Park West & W 72 St
# 15851894  2022-07-29 14:56:29.969           E 20 St & Park Ave
# 13043140  2022-07-26 12:53:40.960      Bushwick Ave & Stagg St
# 12892275  2022-07-24 13:21:31.825               30 Ave & 41 St
# 24144820  2022-10-11 08:30:20.392      Madison St & Clinton St
#
#          start_station_id              end_station_name end_station_id  \
# 23031359          6098.10                E 9 St & 5 Ave        5872.10
# 4214833           6224.03               S 5 Pl & S 5 St        5125.03
# 27380825          5001.08      South St & Gouverneur Ln        4953.04
# 26400613          5772.07         Spruce St & Nassau St        5137.10
# 28333068          8336.02           Broadway & W 165 St        8191.01
# ...                   ...                           ...            ...
# 17567286          7141.07            W 63 St & Broadway        7052.01
# 15851894          6055.08         Lafayette St & E 8 St        5788.13
# 13043140          5140.06  St Johns Pl & Washington Ave        4001.09
# 12892275          6812.06     Shore Blvd & Astoria Park        7271.01
# 24144820          5190.07        St James Pl & Pearl St        5167.06
#
#           start_lat  start_lng  ...  member_casual        date Precipitation  \
# 23031359  40.739888 -73.989586  ...         member  2022-10-19           0.0
# 4214833   40.744751 -73.999154  ...         casual  2022-04-13           0.0
# 27380825  40.705693 -74.016777  ...         member  2022-11-12           2.3
# 26400613  40.731480 -74.010915  ...         member  2022-11-09           0.0
# 28333068  40.848467 -73.936064  ...         member  2022-12-29           0.0
# ...             ...        ...  ...            ...         ...           ...
# 17567286  40.775794 -73.976206  ...         member  2022-08-01          10.4
# 15851894  40.738274 -73.987520  ...         member  2022-07-29           0.5
# 13043140  40.709897 -73.940080  ...         member  2022-07-26           0.0
# 12892275  40.763422 -73.914142  ...         member  2022-07-24           0.0
# 24144820  40.712690 -73.987763  ...         casual  2022-10-11           0.0
#
#          avgtemp  trips_per_day  tripduration  tripduration(mins)  \
# 23031359    10.0          99852           341                   6
# 4214833     15.4          98764          2767                  46
# 27380825    19.7         113802           642                  11
# 26400613     8.7          95500           473                   8
# 28333068     6.4          51674           279                   5
# ...          ...            ...           ...                 ...
# 17567286    23.1          98167           446                   7
# 15851894    28.2         114611           264                   4
# 13043140    25.9         122455          1949                  32
# 12892275    31.1          99639           870                  15
# 24144820    17.0         112059           216                   4
#
#                       usertype  month value
# 23031359   member_classic_bike     10     1
# 4214833    casual_classic_bike      4     1
# 27380825   member_classic_bike     11     1
# 26400613  member_electric_bike     11     1
# 28333068  member_electric_bike     12     1
# ...                        ...    ...   ...
# 17567286   member_classic_bike      8     1
# 15851894   member_classic_bike      7     1
# 13043140   member_classic_bike      7     1
# 12892275   member_classic_bike      7     1
# 24144820   casual_classic_bike     10     1
#
# [2983817 rows x 22 columns]

# %%
# Build a Series of counts for each trip pair
pair_counts = (df.value_counts(subset=['start_station_name', 'end_station_name']).rename('trip_count'))

# Map those counts back to df
df['trip_count'] = df.set_index(['start_station_name', 'end_station_name']) \
                     .index.map(pair_counts) \
                     .fillna(0) \
                     .astype(int)

# %%
df.head()
# Out:
#                    ride_id  rideable_type               started_at  \
# 23031359  51561596962D6D34   classic_bike  2022-10-19 19:05:17.329
# 4214833   8EC10B67BE1C76F4   classic_bike  2022-04-13 14:57:39.816
# 27380825  D8E629127787A5D5   classic_bike  2022-11-12 16:07:20.481
# 26400613  4FF2A3FCAC3D21C6  electric_bike  2022-11-09 07:24:23.803
# 28333068  0FCCB939FC94D28C  electric_bike  2022-12-29 14:49:21.643
#
#                          ended_at        start_station_name start_station_id  \
# 23031359  2022-10-19 19:10:58.132        Broadway & E 21 St          6098.10
# 4214833   2022-04-13 15:43:47.279           W 22 St & 8 Ave          6224.03
# 27380825  2022-11-12 16:18:02.598     Little West St & 1 Pl          5001.08
# 26400613  2022-11-09 07:32:16.316       Morton St & West St          5772.07
# 28333068  2022-12-29 14:54:01.034  Wadsworth Ave & W 179 St          8336.02
#
#                   end_station_name end_station_id  start_lat  start_lng  ...  \
# 23031359            E 9 St & 5 Ave        5872.10  40.739888 -73.989586  ...
# 4214833            S 5 Pl & S 5 St        5125.03  40.744751 -73.999154  ...
# 27380825  South St & Gouverneur Ln        4953.04  40.705693 -74.016777  ...
# 26400613     Spruce St & Nassau St        5137.10  40.731480 -74.010915  ...
# 28333068       Broadway & W 165 St        8191.01  40.848467 -73.936064  ...
#
#                 date  Precipitation avgtemp trips_per_day  tripduration  \
# 23031359  2022-10-19            0.0    10.0         99852           341
# 4214833   2022-04-13            0.0    15.4         98764          2767
# 27380825  2022-11-12            2.3    19.7        113802           642
# 26400613  2022-11-09            0.0     8.7         95500           473
# 28333068  2022-12-29            0.0     6.4         51674           279
#
#           tripduration(mins)              usertype  month  value trip_count
# 23031359                   6   member_classic_bike     10      1         64
# 4214833                   46   casual_classic_bike      4      1          3
# 27380825                  11   member_classic_bike     11      1         67
# 26400613                   8  member_electric_bike     11      1          3
# 28333068                   5  member_electric_bike     12      1         10
#
# [5 rows x 23 columns]

# %%
df.describe()
# Out:
#           start_lat     start_lng       end_lat       end_lng  Precipitation  \
# count  2.983817e+06  2.983817e+06  2.980142e+06  2.980142e+06   2.983817e+06
# mean   4.074055e+01 -7.397525e+01  4.074035e+01 -7.397535e+01   2.367569e+00
# std    3.892089e-02  2.579353e-02  3.885638e-02  2.581259e-02   6.067513e+00
# min    4.063332e+01 -7.402747e+01  4.056000e+01 -7.410000e+01   0.000000e+00
# 25%    4.071602e+01 -7.399379e+01  4.071582e+01 -7.399380e+01   0.000000e+00
# 50%    4.073936e+01 -7.398163e+01  4.073932e+01 -7.398166e+01   0.000000e+00
# 75%    4.076319e+01 -7.395928e+01  4.076313e+01 -7.395943e+01   8.000000e-01
# max    4.088238e+01 -7.387859e+01  4.096000e+01 -7.378000e+01   4.500000e+01
#
#             avgtemp  trips_per_day  tripduration  tripduration(mins)  \
# count  2.983817e+06   2.983817e+06  2.983817e+06        2.983817e+06
# mean   1.712533e+01   9.518882e+04  1.090162e+03        1.816862e+01
# std    8.555726e+00   2.787280e+04  1.531418e+04        2.552374e+02
# min   -1.170000e+01   2.848000e+03 -3.341000e+03       -5.600000e+01
# 25%    1.140000e+01   7.487300e+04  3.480000e+02        6.000000e+00
# 50%    1.790000e+01   1.036390e+05  6.100000e+02        1.000000e+01
# 75%    2.410000e+01   1.173210e+05  1.079000e+03        1.800000e+01
# max    3.130000e+01   1.350720e+05  1.337780e+07        2.229630e+05
#
#               month      value    trip_count
# count  2.983817e+06  2983817.0  2.983817e+06
# mean   7.047576e+00        1.0  3.730713e+01
# std    2.912009e+00        0.0  6.550601e+01
# min    1.000000e+00        1.0  0.000000e+00
# 25%    5.000000e+00        1.0  6.000000e+00
# 50%    7.000000e+00        1.0  1.800000e+01
# 75%    9.000000e+00        1.0  4.200000e+01
# max    1.200000e+01        1.0  1.165000e+03

# %%
df.shape
# Out:
# (2983817, 23)

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'date', 'Precipitation', 'avgtemp', 'trips_per_day',
#        'tripduration', 'tripduration(mins)', 'usertype', 'month', 'value',
#        'trip_count'],
#       dtype='object')

# %%
df_map = df[['start_station_name', 'start_lat', 'start_lng', 'end_station_name', 'end_lat', 'end_lng', 'trip_count']]
df_map.head()
# Out:
#                 start_station_name  start_lat  start_lng  \
# 23031359        Broadway & E 21 St  40.739888 -73.989586
# 4214833            W 22 St & 8 Ave  40.744751 -73.999154
# 27380825     Little West St & 1 Pl  40.705693 -74.016777
# 26400613       Morton St & West St  40.731480 -74.010915
# 28333068  Wadsworth Ave & W 179 St  40.848467 -73.936064
#
#                   end_station_name    end_lat    end_lng  trip_count
# 23031359            E 9 St & 5 Ave  40.732759 -73.995817          64
# 4214833            S 5 Pl & S 5 St  40.710451 -73.960876           3
# 27380825  South St & Gouverneur Ln  40.703554 -74.006702          67
# 26400613     Spruce St & Nassau St  40.711464 -74.005524           3
# 28333068       Broadway & W 165 St  40.839137 -73.941409          10

# %%
df_map_drop = df_map.copy()
df_map_drop.drop_duplicates(inplace=True)

# %%
df_map_drop.dropna(inplace=True)

# %%
df_map_drop.shape
# Out:
# (833324, 7)

# %%
df_map_drop.rename(columns={
    'Latitude_x': 'start_lat',
    'Longitude_x': 'start_lng',
    'Latitude_y': 'end_lat',
    'Longitude_y': 'end_lng'
}, inplace=True)

# %%
df_map_drop.head()
# Out:
#                 start_station_name  start_lat  start_lng  \
# 23031359        Broadway & E 21 St  40.739888 -73.989586
# 4214833            W 22 St & 8 Ave  40.744751 -73.999154
# 27380825     Little West St & 1 Pl  40.705693 -74.016777
# 26400613       Morton St & West St  40.731480 -74.010915
# 28333068  Wadsworth Ave & W 179 St  40.848467 -73.936064
#
#                   end_station_name    end_lat    end_lng  trip_count
# 23031359            E 9 St & 5 Ave  40.732759 -73.995817          64
# 4214833            S 5 Pl & S 5 St  40.710451 -73.960876           3
# 27380825  South St & Gouverneur Ln  40.703554 -74.006702          67
# 26400613     Spruce St & Nassau St  40.711464 -74.005524           3
# 28333068       Broadway & W 165 St  40.839137 -73.941409          10

# %%
df_kepler = df_map_drop.drop(columns=["start_station_name", "end_station_name"])

# %%
df_kepler.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
df_kepler.dropna(inplace=True)

# %%
df_kepler.replace(r'\t', ' ', regex=True, inplace=True)
df_kepler.to_csv(os.path.join(path, '02_Prepared_Data', 'kepler_clean_csv.csv'), index=False, encoding='utf-8')

# %%
df_kepler.head()
# Out:
#           start_lat  start_lng    end_lat    end_lng  trip_count
# 23031359  40.739888 -73.989586  40.732759 -73.995817          64
# 4214833   40.744751 -73.999154  40.710451 -73.960876           3
# 27380825  40.705693 -74.016777  40.703554 -74.006702          67
# 26400613  40.731480 -74.010915  40.711464 -74.005524           3
# 28333068  40.848467 -73.936064  40.839137 -73.941409          10

# %%
for col in ['start_lat', 'start_lng', 'end_lat', 'end_lng']:
    df_kepler[col] = pd.to_numeric(df_kepler[col], errors='coerce')

# %%
df_kepler.replace([np.inf, -np.inf], np.nan, inplace=True)
df_kepler.dropna(subset=['start_lat', 'start_lng', 'end_lat', 'end_lng'], inplace=True)

# %%
df_kepler_final = df_kepler[['start_lat', 'start_lng', 'end_lat', 'end_lng', 'trip_count']].copy()

# %%
df_kepler_final.head()
# Out:
#           start_lat  start_lng    end_lat    end_lng  trip_count
# 23031359  40.739888 -73.989586  40.732759 -73.995817          64
# 4214833   40.744751 -73.999154  40.710451 -73.960876           3
# 27380825  40.705693 -74.016777  40.703554 -74.006702          67
# 26400613  40.731480 -74.010915  40.711464 -74.005524           3
# 28333068  40.848467 -73.936064  40.839137 -73.941409          10

# %%
df_kepler.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 833324 entries, 23031359 to 13043140
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   start_lat   833324 non-null  float64
#  1   start_lng   833324 non-null  float64
#  2   end_lat     833324 non-null  float64
#  3   end_lng     833324 non-null  float64
#  4   trip_count  833324 non-null  int32
# dtypes: float64(4), int32(1)
# memory usage: 35.0 MB

# %%
map_1 = KeplerGl(height=600)
map_1.add_data(data=df_kepler_final, name='Citibike NY 2022')
map_1
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(data={'Citibike NY 2022': {'index': [23031359, 4214833, 27380825, 26400613, 28333068, 4034350, 360836…

# %% [markdown]
# ## I changed the colour points to be green at start and red at end, this felt appropriate and colours match nicely. I reduced the size of the lines so that congregated lines show up better. The Arc begins light green and ends pinkinsh, following the colour style. Point size reduced as well.

# %% [markdown]
# ## A large amount of people are cycling to or down Empire state trail - perhaps exercising? A large amoutn of trips end at 10th Ave and W 26th Street. This area has art galleries, a park, and a night club. A large amount of trips are to or around central park - again perhaps recreation. There are also a large amount of trips from residential areas south of Central Park to the nearby Theatre Area at 10th Ave and 52/53rd street.

# %%
config = map_1.config

# %%
config
# Out:
# {'version': 'v1',
#  'config': {'visState': {'filters': [{'dataId': ['Citibike NY 2022'],
#      'id': 'o0pxc9lra',
#      'name': ['trip_count'],
#      'type': 'range',
#      'value': [99, 99],
#      'plotType': 'histogram',
#      'animationWindow': 'free',
#      'yAxis': None,
#      'view': 'side',
#      'speed': 1,
#      'enabled': True}],
#    'layers': [{'id': 'kzxkpyp',
#      'type': 'point',
#      'config': {'dataId': 'Citibike NY 2022',
#       'label': 'start',
#       'color': [61, 122, 62],
#       'highlightColor': [252, 242, 26, 255],
#       'columns': {'lat': 'start_lat', 'lng': 'start_lng'},
#       'isVisible': True,
#       'visConfig': {'radius': 10,
#        'fixedRadius': False,
#        'opacity': 0.8,
#        'outline': False,
#        'thickness': 2,
#        'strokeColor': None,
#        'colorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
#          '#C70039',
#          '#E3611C',
#          '#F1920E',
#          '#FFC300']},
#        'strokeColorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
#          '#C70039',
#          '#E3611C',
#          '#F1920E',
#          '#FFC300']},
#        'radiusRange': [0, 50],
#        'filled': True},
#       'hidden': False,
#       'textLabel': [{'field': None,
#         'color': [255, 255, 255],
#         'size': 18,
#         'offset': [0, 0],
#         'anchor': 'start',
#         'alignment': 'center',
#         'outlineWidth': 0,
#         'outlineColor': [255, 0, 0, 255],
#         'background': False,
#         'backgroundColor': [0, 0, 200, 255]}]},
#      'visualChannels': {'colorField': None,
#       'colorScale': 'quantile',
#       'strokeColorField': None,
#       'strokeColorScale': 'quantile',
#       'sizeField': None,
#       'sizeScale': 'linear'}},
#     {'id': 'dxivek',
#      'type': 'point',
#      'config': {'dataId': 'Citibike NY 2022',
#       'label': 'end',
#       'color': [187, 0, 0],
#       'highlightColor': [252, 242, 26, 255],
#       'columns': {'lat': 'end_lat', 'lng': 'end_lng'},
#       'isVisible': True,
#       'visConfig': {'radius': 10,
#        'fixedRadius': False,
#        'opacity': 0.8,
#        'outline': False,
#        'thickness': 2,
#        'strokeColor': None,
#        'colorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
#          '#C70039',
#          '#E3611C',
#          '#F1920E',
#          '#FFC300']},
#        'strokeColorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
#          '#C70039',
#          '#E3611C',
#          '#F1920E',
#          '#FFC300']},
#        'radiusRange': [0, 50],
#        'filled': True},
#       'hidden': False,
#       'textLabel': [{'field': None,
#         'color': [255, 255, 255],
#         'size': 18,
#         'offset': [0, 0],
#         'anchor': 'start',
#         'alignment': 'center',
#         'outlineWidth': 0,
#         'outlineColor': [255, 0, 0, 255],
#         'background': False,
#         'backgroundColor': [0, 0, 200, 255]}]},
#      'visualChannels': {'colorField': None,
#       'colorScale': 'quantile',
#       'strokeColorField': None,
#       'strokeColorScale': 'quantile',
#       'sizeField': None,
#       'sizeScale': 'linear'}},
#     {'id': '9zu8ym9',
#      'type': 'arc',
#      'config': {'dataId': 'Citibike NY 2022',
#       'label': 'start -> end arc',
#       'color': [90, 115, 90],
#       'highlightColor': [252, 242, 26, 255],
#       'columns': {'lat0': 'start_lat',
#        'lng0': 'start_lng',
#        'lat1': 'end_lat',
#        'lng1': 'end_lng'},
#       'isVisible': True,
#       'visConfig': {'opacity': 1,
#        'thickness': 2,
#        'colorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
#          '#C70039',
#          '#E3611C',
#          '#F1920E',
#          '#FFC300']},
#        'sizeRange': [0, 10],
#        'targetColor': [165, 92, 92]},
#       'hidden': False,
#       'textLabel': [{'field': None,
#         'color': [255, 255, 255],
#         'size': 18,
#         'offset': [0, 0],
#         'anchor': 'start',
#         'alignment': 'center',
#         'outlineWidth': 0,
#         'outlineColor': [255, 0, 0, 255],
#         'background': False,
#         'backgroundColor': [0, 0, 200, 255]}]},
#      'visualChannels': {'colorField': None,
#       'colorScale': 'quantile',
#       'sizeField': None,
#       'sizeScale': 'linear'}},
#     {'id': 'qhbfqal',
#      'type': 'line',
#      'config': {'dataId': 'Citibike NY 2022',
#       'label': 'start -> end line',
#       'color': [136, 87, 44],
#       'highlightColor': [252, 242, 26, 255],
#       'columns': {'lat0': 'start_lat',
#        'lng0': 'start_lng',
#        'lat1': 'end_lat',
#        'lng1': 'end_lng'},
#       'isVisible': False,
#       'visConfig': {'opacity': 0.8,
#        'thickness': 2,
#        'colorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
#          '#C70039',
#          '#E3611C',
#          '#F1920E',
#          '#FFC300']},
#        'sizeRange': [0, 10],
#        'targetColor': None,
#        'elevationScale': 1},
#       'hidden': False,
#       'textLabel': [{'field': None,
#         'color': [255, 255, 255],
#         'size': 18,
#         'offset': [0, 0],
#         'anchor': 'start',
#         'alignment': 'center',
#         'outlineWidth': 0,
#         'outlineColor': [255, 0, 0, 255],
#         'background': False,
#         'backgroundColor': [0, 0, 200, 255]}]},
#      'visualChannels': {'colorField': None,
#       'colorScale': 'quantile',
#       'sizeField': None,
#       'sizeScale': 'linear'}}],
#    'effects': [],
#    'interactionConfig': {'tooltip': {'fieldsToShow': {'Citibike NY 2022': [{'name': 'trip_count',
#         'format': None}]},
#      'compareMode': False,
#      'compareType': 'absolute',
#      'enabled': True},
#     'brush': {'size': 0.5, 'enabled': False},
#     'geocoder': {'enabled': False},
#     'coordinate': {'enabled': False}},
#    'layerBlending': 'normal',
#    'overlayBlending': 'normal',
#    'splitMaps': [],
#    'animationConfig': {'currentTime': None, 'speed': 1},
#    'editor': {'features': [], 'visible': True}},
#   'mapState': {'bearing': 0,
#    'dragRotate': False,
#    'latitude': 40.74954107834203,
#    'longitude': -73.98086523636243,
#    'pitch': 0,
#    'zoom': 11.644176750750857,
#    'isSplit': False,
#    'isViewportSynced': True,
#    'isZoomLocked': False,
#    'splitMapViewports': []},
#   'mapStyle': {'styleType': 'dark-matter',
#    'topLayerGroups': {},
#    'visibleLayerGroups': {'label': True,
#     'road': True,
#     'border': False,
#     'building': True,
#     'water': True,
#     'land': True,
#     '3d building': False},
#    'threeDBuildingColor': [15.035172933000911,
#     15.035172933000911,
#     15.035172933000911],
#    'backgroundColor': [0, 0, 0],
#    'mapStyles': {}}}}

# %%
map_1.save_to_html(file_name = 'NY_Citibike_2022.html', read_only = False, config = config)
# Out:
# Map saved to NY_Citibike_2022.html!
